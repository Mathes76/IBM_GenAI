# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # Regression Models with Keras
#
# Estimated time needed: **45** mins

# %% [markdown]
# ## Introduction

# %% [markdown]
# As we discussed in the videos, despite the popularity of more powerful libraries such as PyToch and TensorFlow, they are not easy to use and have a steep learning curve. So, for people who are just starting to learn deep learning, there is no better library to use other than the Keras library.
#
# Keras is a high-level API for building deep learning models. It has gained favor for its ease of use and syntactic simplicity facilitating fast development. As you will see in this lab and the other labs in this course, building a very complex deep learning network can be achieved with Keras with only few lines of code. You will appreciate Keras even more, once you learn how to build deep models using PyTorch and TensorFlow in the other courses.
#
# So, in this lab, you will learn how to use the Keras library to build a regression model.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build a regression model
# * Download and clean the data set
# * Build a neural network
# * Train and test the network

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Download and Clean the Data Set</a>
# 2. <a href="#item32">Import Keras Packages</a>
# 3. <a href="#item33">Build a Neural Network</a>
# 4. <a href="#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id="item31"></a>

# %% [markdown]
# ## Download and Clean the  Data Set

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented. 
# If you run this notebook on a different environment, e.g. your desktop, you may need to uncomment and install certain libraries.
# !pip install numpy==2.0.2
# !pip install pandas==2.2.2
# !pip install tensorflow_cpu==2.18.0
# Out:
# Collecting tensorflow_cpu==2.18.0
#   Using cached tensorflow_cpu-2.18.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting tensorflow-intel==2.18.0 (from tensorflow_cpu==2.18.0)
#   Using cached tensorflow_intel-2.18.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (79.0.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.71.0)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0)
#   Using cached tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: keras>=3.5.0 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.9.2)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.13.0)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0)
#   Using cached ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.0.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.45.1)
# Requirement already satisfied: rich in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (14.0.0)
# Requirement already satisfied: namex in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.0.9)
# Requirement already satisfied: optree in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\andie\ibm\genai\notebooks\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.1.2)
# Using cached tensorflow_cpu-2.18.0-cp312-cp312-win_amd64.whl (7.6 kB)
# Using cached tensorflow_intel-2.18.0-cp312-cp312-win_amd64.whl (390.3 MB)
# Using cached ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl (127 kB)
# Using cached tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
# Installing collected packages: ml-dtypes, tensorboard, tensorflow-intel, tensorflow_cpu
#
#   Attempting uninstall: ml-dtypes
#
#     Found existing installation: ml_dtypes 0.5.1
#
#     Uninstalling ml_dtypes-0.5.1:
#
#       Successfully uninstalled ml_dtypes-0.5.1
#
#   Attempting uninstall: tensorboard
#
#     Found existing installation: tensorboard 2.19.0
#
#    ---------- ----------------------------- 1/4 [tensorboard]
#     Uninstalling tensorboard-2.19.0:
#    ---------- ----------------------------- 1/4 [tensorboard]
#       Successfully uninstalled tensorboard-2.19.0
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    ---------- ----------------------------- 1/4 [tensorboard]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    -------------------- ------------------- 2/4 [tensorflow-intel]
#    ---------------------------------------- 4/4 [tensorflow_cpu]
#
# Successfully installed ml-dtypes-0.4.1 tensorboard-2.18.0 tensorflow-intel-2.18.0 tensorflow_cpu-2.18.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.19.0 requires ml-dtypes<1.0.0,>=0.5.1, but you have ml-dtypes 0.4.1 which is incompatible.
# tensorflow 2.19.0 requires tensorboard~=2.19.0, but you have tensorboard 2.18.0 which is incompatible.

# %% [markdown]
# ##### To use Keras, you will also need to install a backend framework – such as TensorFlow.
#
# If you install TensorFlow 2.16 or above, it will install Keras by default.
#
# We are using the CPU version of tensorflow since we are dealing with smaller datasets.
# You may install the GPU version of tensorflow on your machine to accelarate the processing of larger datasets

# %%
import pandas as pd
import numpy as np
import keras

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# * Cement
# * Blast furnace slag
# * Fly ash
# * Water
# * Superplasticizer
# * Coarse aggregate
# * Fine aggregate

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
filepath='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

# %%
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ##  Import Keras Packages
#
# ##### Let's import the rest of the packages from the Keras library that we will need to build our regression model.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - 54ms/step - loss: 1647.7252 - val_loss: 1131.8529
# Epoch 2/100
# 23/23 - 0s - 6ms/step - loss: 1516.6938 - val_loss: 998.3723
# Epoch 3/100
# 23/23 - 0s - 6ms/step - loss: 1310.9103 - val_loss: 792.1736
# Epoch 4/100
# 23/23 - 0s - 6ms/step - loss: 998.7190 - val_loss: 528.4774
# Epoch 5/100
# 23/23 - 0s - 6ms/step - loss: 635.2155 - val_loss: 296.8864
# Epoch 6/100
# 23/23 - 0s - 6ms/step - loss: 360.9033 - val_loss: 173.7070
# Epoch 7/100
# 23/23 - 0s - 6ms/step - loss: 249.3870 - val_loss: 151.4172
# Epoch 8/100
# 23/23 - 0s - 6ms/step - loss: 222.5889 - val_loss: 151.7419
# Epoch 9/100
# 23/23 - 0s - 6ms/step - loss: 208.5611 - val_loss: 155.0789
# Epoch 10/100
# 23/23 - 0s - 6ms/step - loss: 198.1189 - val_loss: 152.8097
# Epoch 11/100
# 23/23 - 0s - 6ms/step - loss: 189.1862 - val_loss: 152.6111
# Epoch 12/100
# 23/23 - 0s - 6ms/step - loss: 183.7914 - val_loss: 152.2273
# Epoch 13/100
# 23/23 - 0s - 6ms/step - loss: 177.1802 - val_loss: 151.3927
# Epoch 14/100
# 23/23 - 0s - 6ms/step - loss: 172.7492 - val_loss: 150.9406
# Epoch 15/100
# 23/23 - 0s - 10ms/step - loss: 169.0479 - val_loss: 152.3034
# Epoch 16/100
# 23/23 - 0s - 6ms/step - loss: 165.3975 - val_loss: 150.0163
# Epoch 17/100
# 23/23 - 0s - 6ms/step - loss: 162.2343 - val_loss: 151.8823
# Epoch 18/100
# 23/23 - 0s - 6ms/step - loss: 158.7788 - val_loss: 151.4810
# Epoch 19/100
# 23/23 - 0s - 6ms/step - loss: 156.5628 - val_loss: 150.6883
# Epoch 20/100
# 23/23 - 0s - 6ms/step - loss: 154.0404 - val_loss: 152.6066
# Epoch 21/100
# 23/23 - 0s - 6ms/step - loss: 151.7598 - val_loss: 152.8656
# Epoch 22/100
# 23/23 - 0s - 6ms/step - loss: 150.1194 - val_loss: 153.5670
# Epoch 23/100
# 23/23 - 0s - 6ms/step - loss: 147.6010 - val_loss: 153.8468
# Epoch 24/100
# 23/23 - 0s - 6ms/step - loss: 145.9502 - val_loss: 154.2829
# Epoch 25/100
# 23/23 - 0s - 6ms/step - loss: 144.1593 - val_loss: 154.5443
# Epoch 26/100
# 23/23 - 0s - 6ms/step - loss: 143.2215 - val_loss: 153.4009
# Epoch 27/100
# 23/23 - 0s - 6ms/step - loss: 141.9046 - val_loss: 155.5595
# Epoch 28/100
# 23/23 - 0s - 6ms/step - loss: 140.0253 - val_loss: 157.3159
# Epoch 29/100
# 23/23 - 0s - 6ms/step - loss: 137.6082 - val_loss: 155.8258
# Epoch 30/100
# 23/23 - 0s - 6ms/step - loss: 136.4118 - val_loss: 153.4796
# Epoch 31/100
# 23/23 - 0s - 6ms/step - loss: 135.0941 - val_loss: 158.8276
# Epoch 32/100
# 23/23 - 0s - 6ms/step - loss: 133.8486 - val_loss: 155.6986
# Epoch 33/100
# 23/23 - 0s - 6ms/step - loss: 132.2648 - val_loss: 155.7518
# Epoch 34/100
# 23/23 - 0s - 7ms/step - loss: 129.6721 - val_loss: 155.3326
# Epoch 35/100
# 23/23 - 0s - 6ms/step - loss: 127.9760 - val_loss: 156.3850
# Epoch 36/100
# 23/23 - 0s - 6ms/step - loss: 126.0415 - val_loss: 158.9600
# Epoch 37/100
# 23/23 - 0s - 6ms/step - loss: 124.4080 - val_loss: 160.5109
# Epoch 38/100
# 23/23 - 0s - 6ms/step - loss: 122.7888 - val_loss: 156.8238
# Epoch 39/100
# 23/23 - 0s - 7ms/step - loss: 120.9531 - val_loss: 154.8152
# Epoch 40/100
# 23/23 - 0s - 6ms/step - loss: 119.1369 - val_loss: 156.1658
# Epoch 41/100
# 23/23 - 0s - 6ms/step - loss: 116.7123 - val_loss: 156.3175
# Epoch 42/100
# 23/23 - 0s - 6ms/step - loss: 115.2121 - val_loss: 154.7542
# Epoch 43/100
# 23/23 - 0s - 6ms/step - loss: 113.4286 - val_loss: 154.1675
# Epoch 44/100
# 23/23 - 0s - 6ms/step - loss: 110.9938 - val_loss: 154.6178
# Epoch 45/100
# 23/23 - 0s - 6ms/step - loss: 108.8676 - val_loss: 148.3906
# Epoch 46/100
# 23/23 - 0s - 6ms/step - loss: 106.4912 - val_loss: 152.0998
# Epoch 47/100
# 23/23 - 0s - 6ms/step - loss: 103.7057 - val_loss: 150.4016
# Epoch 48/100
# 23/23 - 0s - 6ms/step - loss: 101.6515 - val_loss: 149.5734
# Epoch 49/100
# 23/23 - 0s - 6ms/step - loss: 98.8427 - val_loss: 148.5655
# Epoch 50/100
# 23/23 - 0s - 6ms/step - loss: 95.7555 - val_loss: 146.9278
# Epoch 51/100
# 23/23 - 0s - 6ms/step - loss: 92.8882 - val_loss: 144.3040
# Epoch 52/100
# 23/23 - 0s - 6ms/step - loss: 90.6888 - val_loss: 147.5826
# Epoch 53/100
# 23/23 - 0s - 6ms/step - loss: 88.8384 - val_loss: 138.5104
# Epoch 54/100
# 23/23 - 0s - 6ms/step - loss: 85.5141 - val_loss: 140.2023
# Epoch 55/100
# 23/23 - 0s - 6ms/step - loss: 81.9895 - val_loss: 134.0734
# Epoch 56/100
# 23/23 - 0s - 6ms/step - loss: 79.2659 - val_loss: 138.2917
# Epoch 57/100
# 23/23 - 0s - 6ms/step - loss: 76.3224 - val_loss: 130.0660
# Epoch 58/100
# 23/23 - 0s - 6ms/step - loss: 74.3356 - val_loss: 137.6766
# Epoch 59/100
# 23/23 - 0s - 6ms/step - loss: 72.1207 - val_loss: 122.7707
# Epoch 60/100
# 23/23 - 0s - 6ms/step - loss: 70.0386 - val_loss: 134.8859
# Epoch 61/100
# 23/23 - 0s - 6ms/step - loss: 67.4837 - val_loss: 129.4691
# Epoch 62/100
# 23/23 - 0s - 7ms/step - loss: 65.3944 - val_loss: 126.6649
# Epoch 63/100
# 23/23 - 0s - 6ms/step - loss: 63.7386 - val_loss: 124.8629
# Epoch 64/100
# 23/23 - 0s - 6ms/step - loss: 61.5140 - val_loss: 122.9576
# Epoch 65/100
# 23/23 - 0s - 6ms/step - loss: 60.2219 - val_loss: 131.5271
# Epoch 66/100
# 23/23 - 0s - 6ms/step - loss: 58.0267 - val_loss: 123.1278
# Epoch 67/100
# 23/23 - 0s - 6ms/step - loss: 57.0814 - val_loss: 122.2775
# Epoch 68/100
# 23/23 - 0s - 6ms/step - loss: 55.5174 - val_loss: 128.1968
# Epoch 69/100
# 23/23 - 0s - 6ms/step - loss: 53.7713 - val_loss: 122.1487
# Epoch 70/100
# 23/23 - 0s - 6ms/step - loss: 52.2864 - val_loss: 120.8709
# Epoch 71/100
# 23/23 - 0s - 6ms/step - loss: 51.1708 - val_loss: 122.6956
# Epoch 72/100
# 23/23 - 0s - 6ms/step - loss: 49.9359 - val_loss: 122.5525
# Epoch 73/100
# 23/23 - 0s - 6ms/step - loss: 49.2503 - val_loss: 117.5942
# Epoch 74/100
# 23/23 - 0s - 6ms/step - loss: 47.7652 - val_loss: 120.2070
# Epoch 75/100
# 23/23 - 0s - 8ms/step - loss: 46.9601 - val_loss: 126.9832
# Epoch 76/100
# 23/23 - 0s - 9ms/step - loss: 46.5580 - val_loss: 116.1549
# Epoch 77/100
# 23/23 - 0s - 7ms/step - loss: 45.7160 - val_loss: 111.0009
# Epoch 78/100
# 23/23 - 0s - 6ms/step - loss: 44.9154 - val_loss: 130.2014
# Epoch 79/100
# 23/23 - 0s - 6ms/step - loss: 43.9020 - val_loss: 116.3778
# Epoch 80/100
# 23/23 - 0s - 6ms/step - loss: 43.0594 - val_loss: 121.2206
# Epoch 81/100
# 23/23 - 0s - 6ms/step - loss: 42.5738 - val_loss: 125.7714
# Epoch 82/100
# 23/23 - 0s - 6ms/step - loss: 41.7535 - val_loss: 123.3822
# Epoch 83/100
# 23/23 - 0s - 6ms/step - loss: 40.7923 - val_loss: 126.5165
# Epoch 84/100
# 23/23 - 0s - 6ms/step - loss: 40.3495 - val_loss: 117.9849
# Epoch 85/100
# 23/23 - 0s - 6ms/step - loss: 40.0007 - val_loss: 123.1078
# Epoch 86/100
# 23/23 - 0s - 5ms/step - loss: 39.3060 - val_loss: 118.3540
# Epoch 87/100
# 23/23 - 0s - 5ms/step - loss: 38.8255 - val_loss: 118.1334
# Epoch 88/100
# 23/23 - 0s - 5ms/step - loss: 39.2241 - val_loss: 125.2028
# Epoch 89/100
# 23/23 - 0s - 5ms/step - loss: 38.6122 - val_loss: 128.6890
# Epoch 90/100
# 23/23 - 0s - 5ms/step - loss: 38.4473 - val_loss: 123.4023
# Epoch 91/100
# 23/23 - 0s - 6ms/step - loss: 37.2045 - val_loss: 124.4381
# Epoch 92/100
# 23/23 - 0s - 5ms/step - loss: 36.9207 - val_loss: 121.0471
# Epoch 93/100
# 23/23 - 0s - 5ms/step - loss: 36.2639 - val_loss: 122.2171
# Epoch 94/100
# 23/23 - 0s - 6ms/step - loss: 35.8487 - val_loss: 120.4921
# Epoch 95/100
# 23/23 - 0s - 5ms/step - loss: 35.3585 - val_loss: 118.9866
# Epoch 96/100
# 23/23 - 0s - 5ms/step - loss: 35.3480 - val_loss: 123.3711
# Epoch 97/100
# 23/23 - 0s - 5ms/step - loss: 35.3274 - val_loss: 131.7839
# Epoch 98/100
# 23/23 - 0s - 5ms/step - loss: 34.9320 - val_loss: 121.2881
# Epoch 99/100
# 23/23 - 0s - 6ms/step - loss: 34.2788 - val_loss: 132.6647
# Epoch 100/100
# 23/23 - 0s - 6ms/step - loss: 34.3567 - val_loss: 109.2369

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/) to learn about other functions that you can use for prediction or evaluation.</strong>

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 3.0  | Aman  |  Updated the library versions to current |
# | 2020-09-21  | 2.0  | Srishti  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# <hr>
#
# Copyright &copy; [IBM Developer Skills Network](https://cognitiveclass.ai/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://opensource.org/license/mit).
